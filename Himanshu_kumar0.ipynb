# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuKumar79/Himanshu/blob/master/Himanshu_kumar0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[" "," "," ",
   " "," "," ",
   " "," "," "]
print(a[0]+"|"+a[1]+"|"+a[2])
print("-----")
print(a[3]+"|"+a[4]+"|"+a[5])
print("-----")
print(a[6]+"|"+a[7]+"|"+a[8])

for i in range(1,10):
  if "O"==a[0] and "O"==a[1] and "O"==a[2]:
    break
  elif "O"==a[2] and "O"==a[4] and "O"==a[6]:
    break
  elif "O"==a[0] and "O"==a[4] and "O"==a[8]:
    break
  elif "O"==a[2] and "O"==a[5] and "O"==a[8]:    
    break
  elif "O"==a[1] and "O"==a[4] and "O"==a[7]:    
    break
  elif "O"==a[0] and "O"==a[3] and "O"==a[6]:    
    break
  elif "O"==a[6] and "O"==a[7] and "O"==a[8]:   
    break
  elif "O"==a[3] and "O"==a[4] and "O"==a[5]:    
    break
  elif "X"==a[0] and "X"==a[1] and "X"==a[2]:    
    break
  elif "X"==a[2] and "X"==a[4] and "X"==a[6]:    
    break
  elif "X"==a[0] and "X"==a[4] and "X"==a[8]:    
    break
  elif "X"==a[2] and "X"==a[5] and "X"==a[8]:    
    break
  elif "X"==a[1] and "X"==a[4] and "X"==a[7]:    
    break
  elif "X"==a[0] and "X"==a[3] and "X"==a[6]:    
    break
  elif "X"==a[6] and "X"==a[7] and "X"==a[8]:    
    break
  elif "X"==a[3] and "X"==a[4] and "X"==a[5]:
    break
  elif i%2==0:
    while True:
      p=int(input("O Enter you'r postion:"))
      if p<=9:
        if a[p-1]=="X" or a[p-1]=="O":
          print("Alredy assin")      
        elif "O"==a[0] and "O"==a[1] and "O"==a[2]:      
          break
        elif "O"==a[2] and "O"==a[4] and "O"==a[6]:      
          break
        elif "O"==a[0] and "O"==a[4] and "O"==a[8]:      
          break
        elif "O"==a[2] and "O"==a[5] and "O"==a[8]:      
          break
        elif "O"==a[1] and "O"==a[4] and "O"==a[7]:      
          break
        elif "O"==a[0] and "O"==a[3] and "O"==a[6]:      
          break
        elif "O"==a[6] and "O"==a[7] and "O"==a[8]:      
          break
        elif "O"==a[3] and "O"==a[4] and "O"==a[5]:      
          break
        elif "X"==a[0] and "X"==a[1] and "X"==a[2]:      
          break
        elif "X"==a[2] and "X"==a[4] and "X"==a[6]:      
          break
        elif "X"==a[0] and "X"==a[4] and "X"==a[8]:      
          break
        elif "X"==a[2] and "X"==a[5] and "X"==a[8]:      
          break
        elif "X"==a[1] and "X"==a[4] and "X"==a[7]:      
          break
        elif "X"==a[0] and "X"==a[3] and "X"==a[6]:      
          break
        elif "X"==a[6] and "X"==a[7] and "X"==a[8]:      
          break
        elif "X"==a[3] and "X"==a[4] and "X"==a[5]:      
          break
        else:
          a.pop(p-1)
          a.insert(p-1,"O")
          print(a[0]+"|"+a[1]+"|"+a[2])
          print("-----")
          print(a[3]+"|"+a[4]+"|"+a[5])
          print("-----")
          print(a[6]+"|"+a[7]+"|"+a[8])
          break
      else:
        print("Invalid input")
  else:
    while True:
      p=int(input("X Enter you'r postion:"))
      if p<=9:
        if a[p-1]=="O" or a[p-1]=="X":
              print("Alredy assin")
        elif "X"==a[0] and "X"==a[1] and "X"==a[2]:
          break
        elif "X"==a[2] and "X"==a[4] and "X"==a[6]:
          break
        elif "X"==a[0] and "X"==a[4] and "X"==a[8]:
          break
        elif "X"==a[2] and "X"==a[5] and "X"==a[8]:
          break
        elif "X"==a[1] and "X"==a[4] and "X"==a[7]:
          break
        elif "X"==a[0] and "X"==a[3] and "X"==a[6]:
          break
        elif "X"==a[6] and "X"==a[7] and "X"==a[8]:
          break
        elif "X"==a[3] and "X"==a[4] and "X"==a[5]:
          break
        elif "O"==a[0] and "O"==a[1] and "O"==a[2]:
          break
        elif "O"==a[2] and "O"==a[4] and "O"==a[6]:
          break
        elif "O"==a[0] and "O"==a[4] and "O"==a[8]:
          break
        elif "O"==a[2] and "O"==a[5] and "O"==a[8]:
          break
        elif "O"==a[1] and "O"==a[4] and "O"==a[7]:
          break
        elif "O"==a[0] and "O"==a[3] and "O"==a[6]:
          break
        elif "O"==a[6] and "O"==a[7] and "O"==a[8]:
          break
        elif "O"==a[3] and "O"==a[4] and "O"==a[5]:
          break
        else:
          a.pop(p-1)
          a.insert(p-1,"X")
          print(a[0]+"|"+a[1]+"|"+a[2])
          print("-----")
          print(a[3]+"|"+a[4]+"|"+a[5])
          print("-----")
          print(a[6]+"|"+a[7]+"|"+a[8])
          break
      else:
        print("Invalid Number")


if "O"==a[0] and "O"==a[1] and "O"==a[2]:
  print("O is winner")
elif "O"==a[2] and "O"==a[4] and "O"==a[6]:
  print("O is winner")
elif "O"==a[0] and "O"==a[4] and "O"==a[8]:
  print("O is winner")
elif "O"==a[2] and "O"==a[5] and "O"==a[8]:
  print("O is winner")
elif "O"==a[1] and "O"==a[4] and "O"==a[7]:
  print("O is winner")
elif "O"==a[0] and "O"==a[3] and "O"==a[6]:
  print("O is winner")
elif "O"==a[6] and "O"==a[7] and "O"==a[8]:
  print("O is winner")
elif "O"==a[3] and "O"==a[4] and "O"==a[5]:
  print("O is winner")
elif "X"==a[0] and "X"==a[1] and "X"==a[2]:
  print("X is winner")
elif "X"==a[2] and "X"==a[4] and "X"==a[6]:
  print("X is winner")
elif "X"==a[0] and "X"==a[4] and "X"==a[8]:
  print("X is winner")
elif "X"==a[2] and "X"==a[5] and "X"==a[8]:
  print("X is winner")
elif "X"==a[1] and "X"==a[4] and "X"==a[7]:
  print("X is winner")
elif "X"==a[0] and "X"==a[3] and "X"==a[6]:
  print("X is winner")
elif "X"==a[6] and "X"==a[7] and "X"==a[8]:
  print("X is winner")
elif "X"==a[3] and "X"==a[4] and "X"==a[5]:
  print("X is winner")
else:
  print("Tie")
# Out:
#  | |
# -----
#  | |
# -----
#  | |
# X Enter you'r postion:50
# Invalid Number
# X Enter you'r postion:12
# Invalid Number
# X Enter you'r postion:1
# X| |
# -----
#  | |
# -----
#  | |
# O Enter you'r postion:2
# X|O|
# -----
#  | |
# -----
#  | |
# X Enter you'r postion:4
# X|O|
# -----
# X| |
# -----
#  | |
# O Enter you'r postion:7
# X|O|
# -----
# X| |
# -----
# O| |
# X Enter you'r postion:5
# X|O|
# -----
# X|X|
# -----
# O| |
# O Enter you'r postion:6
# X|O|
# -----
# X|X|O
# -----
# O| |
# X Enter you'r postion:9
# X|O|
# -----
# X|X|O
# -----
# O| |X
# X is winner
